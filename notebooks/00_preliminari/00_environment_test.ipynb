# %% [markdown]
# # 00 - Preliminari
#
# Questo notebook serve per verificare che:
#
# - l'ambiente Python è configurato correttamente
# - il kernel è quello giusto (.venv)
# - le librerie principali funzionano

# %%
print("Environment OK")

# %%
import sys

print("Python path:")
print(sys.executable)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import __version__ as sklearn_version

print("NumPy OK")
print("Pandas OK")
print("Matplotlib OK")
print("Scikit-learn version:", sklearn_version)

# %% [markdown]
# ## Note
#
# Se tutto funziona:
#
# - posso iniziare i capitoli
# - il kernel è configurato correttamente
# - le librerie sono installate
#
# Se qualcosa non funziona:
#
# - controllare ambiente virtuale
# - controllare installazione librerie
