# %%
print("Hello, Hands-On ML")
# Out:
# Hello, Hands-On ML

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import __version__ as sklearn_version

print("NumPy OK")
print("Pandas OK")
print("Scikit-learn version:", sklearn_version)
# Out:
# NumPy OK
# Pandas OK
# Scikit-learn version: 1.8.0
