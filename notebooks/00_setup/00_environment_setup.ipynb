# %% [markdown]
# # 00 - Environment Setup
#
# This notebook is used to verify that:
#
# - the Python environment is correctly configured
# - the kernel is properly set (.venv)
# - the main libraries are working

# %%
print("Environment OK")

# %%
import sys

print("Python path:")
print(sys.executable)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import __version__ as sklearn_version

print("NumPy OK")
print("Pandas OK")
print("Matplotlib OK")
print("Scikit-learn version:", sklearn_version)

# %% [markdown]
# ## Notes
#
# If everything works:
#
# - the environment is correctly configured
# - the kernel is properly set
# - all required libraries are installed
#
# If something fails:
#
# - check virtual environment activation
# - reinstall missing libraries
